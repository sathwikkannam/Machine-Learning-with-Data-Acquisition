# %%
from common import get_set
import pandas as pd
import seaborn as sns

# %%
stationary = ['Laying_down', 'Sitting', 'Standing_up']
movements = ['Squats', 'Jumping', 'Running', 'Walking']

# %%
movements_df = pd.concat(get_set(positions=movements, folder='Class Dataframes'), axis='rows', ignore_index=True)
stationary_df = pd.concat(get_set(positions=stationary, folder='Class Dataframes'), axis='rows', ignore_index=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.pairplot(movements_df, hue='class')

# %%
sns.pairplot(stationary_df, hue='class')
